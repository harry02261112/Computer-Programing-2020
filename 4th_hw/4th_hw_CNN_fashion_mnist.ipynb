# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

# %% [markdown]
# ## Mac OS problem
# Mac OS 在同時執行 numpy, keras, 和 matplotlib 的時候會出現 OMP: Error #15: Initializing libiomp5.dylib, but found libiomp5.dylib already initialized. 的錯誤，造成 kernel 死掉。google 後找到解答是要加上
# <br>import os
# <br>os.environ['KMP_DUPLICATE_LIB_OK']='True'
# <br>就可以跑了
# <br>參考答案：https://github.com/dmlc/xgboost/issues/1715

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
import tensorflow as tf

# %%
from tensorflow.keras.datasets import fashion_mnist as fm

# %%
(x_train, y_train), (x_test, y_test) = fm.load_data()

# %%
print(len(x_train),len(x_test))
# Out:
# 60000 10000

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# ## Using interact to show fashion_mnist data

# %%
from ipywidgets import interact_manual

# %%
def show_data(n):
    plt.imshow(x_train[n], cmap = "Greys")
    print("This is a :", class_names[y_train[n]])

# %%
interact_manual(show_data, n=(0,59999))
# Out:
# interactive(children=(IntSlider(value=29999, description='n', max=59999), Button(description='Run Interact', s…
# <function __main__.show_data(n)>

# %%
x_train = x_train.reshape(60000,28,28,1)/255
x_test = x_test.reshape(10000,28,28,1)/255

# %%
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
from tensorflow.keras.utils import to_categorical

# %%
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %% [markdown]
# ## Using interact to show the result of one-hot

# %%
def syt(n):
    print(y_train[n])
interact_manual(syt, n=(0,9999))
# Out:
# interactive(children=(IntSlider(value=4999, description='n', max=9999), Button(description='Run Interact', sty…
# <function __main__.syt(n)>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import SGD

# %% [markdown]
# ## 增加神經元數

# %%
model = Sequential()
model.add(Conv2D(64, (3, 3), padding='same', input_shape=(28,28,1), activation = 'relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(128, (3, 3), padding='same', activation = 'relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(256, (3, 3), padding='same', activation = 'relu'))
model.add(Flatten())
model.add(Dense(512, activation = 'relu'))
model.add(Dense(10, activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_27 (Conv2D)           (None, 28, 28, 64)        640
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 14, 14, 128)       73856
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 7, 7, 256)         295168
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               6423040
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 6,797,834
# Trainable params: 6,797,834
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer=SGD(lr=0.087), metrics=['accuracy'])

# %%
model.fit(x_train, y_train, batch_size = 128, epochs=10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 121s 2ms/sample - loss: 0.0874 - accuracy: 0.3348
# Epoch 2/10
# 60000/60000 [==============================] - 121s 2ms/sample - loss: 0.0525 - accuracy: 0.6303
# Epoch 3/10
# 60000/60000 [==============================] - 126s 2ms/sample - loss: 0.0383 - accuracy: 0.7239
# Epoch 4/10
# 60000/60000 [==============================] - 124s 2ms/sample - loss: 0.0335 - accuracy: 0.7651
# Epoch 5/10
# 60000/60000 [==============================] - 124s 2ms/sample - loss: 0.0309 - accuracy: 0.7846
# Epoch 6/10
# 60000/60000 [==============================] - 124s 2ms/sample - loss: 0.0291 - accuracy: 0.7973
# Epoch 7/10
# 60000/60000 [==============================] - 122s 2ms/sample - loss: 0.0276 - accuracy: 0.8094
# Epoch 8/10
# 60000/60000 [==============================] - 123s 2ms/sample - loss: 0.0266 - accuracy: 0.8151
# Epoch 9/10
# 60000/60000 [==============================] - 122s 2ms/sample - loss: 0.0255 - accuracy: 0.8244
# Epoch 10/10
# 60000/60000 [==============================] - 122s 2ms/sample - loss: 0.0245 - accuracy: 0.8307

# %%
result = model.predict_classes(x_test)

# %%
def my_predict(n):
    print("This is a :", class_names[result[n]])
    X = x_test[n].reshape(28,28)
    plt.imshow(X, cmap='Greys')

# %%
interact_manual(my_predict, n=(0,9999))
# Out:
# interactive(children=(IntSlider(value=4999, description='n', max=9999), Button(description='Run Interact', sty…
# <function __main__.my_predict(n)>

# %%
score = model.evaluate(x_test, y_test)
score
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.025185762594640254, 0.8274]

# %%
loss,acc =score

# %%
print('測試資料正確率：',acc)
# Out:
# 測試資料正確率： 0.8274

# %%
model.save('4th_hw_CNN_fashion_mnist.h5')
